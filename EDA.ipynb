# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

eda_df = pd.read_csv("training_data.csv")

# 🚀 General statistics summary
print("🔍 General Statistics Summary:")
print(eda_df.describe())

eda_numeric = eda_df.select_dtypes(include=['number'])

plt.figure(figsize=(7, 8))
sns.heatmap(eda_numeric.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("🔍 Feature Correlation Heatmap")
plt.show()

eda_numeric.hist(figsize=(8,12), bins=30, edgecolor='black')
plt.suptitle("📊 Feature Distributions", fontsize=16)
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(x=eda_df["danceability"], y=eda_df["energy"], alpha=0.6, edgecolor=None)
plt.xlabel("Danceability")
plt.ylabel("Energy")
plt.title("📊 Danceability vs. Energy")
plt.show()
# Out:
# 🔍 General Statistics Summary:
#          duration_ms  danceability        energy          key      loudness  \
# count   70842.000000  70842.000000  70842.000000  70842.00000  70842.000000
# mean   203083.759380      0.606114      0.594626      5.24429     -8.124423
# std     55480.590164      0.156328      0.219547      3.59223      3.720273
# min     29747.000000      0.112000      0.000215      0.00000    -22.379000
# 25%    174089.000000      0.502000      0.444000      2.00000    -10.026000
# 50%    202728.000000      0.620000      0.607000      5.00000     -7.433000
# 75%    231360.000000      0.721000      0.763000      8.00000     -5.458250
# max    436000.000000      0.985000      0.999000     11.00000      0.843000
#
#            Compound  TextBlob_Polarity  TextBlob_Subjectivity      Negative  \
# count  70842.000000       70842.000000           70842.000000  70842.000000
# mean       0.377554           0.121101               0.519986      0.088113
# ...
